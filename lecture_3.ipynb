# %% [markdown]
# <a href="https://colab.research.google.com/github/ZeenatSehar1/lecture-1-2-3-/blob/main/lecture_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Set**

# %% [markdown]
# A website wants to count how many unique visitors it had in a day.
# Every time a user visits, their user_id is logged — but users can visit multiple times.
# visits = [101, 102, 103, 101, 104, 102, 105, 103, 105, 106]
# Tasks
# - Find how many unique visitors visited the site.
# - Display the list of unique user_ids (in any order).
# - Compare the total visits vs. unique visitors.

# %%
visits = [101, 102, 103, 101, 104, 102, 105, 103, 105, 106]

unique_visits = set(visits)

print("Unique user IDs:", list(unique_visits))
print("Total visits:", len(visits))
print("Unique visitors:", len(unique_visits))
# Out:
# Unique user IDs: [101, 102, 103, 104, 105, 106]
# Total visits: 10
# Unique visitors: 6

# %% [markdown]
# Count Distinct Words in a Sentence:
# - A user enters a sentence (as a single string).
# - Your task is to count how many distinct words are in the sentence.

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()
unique_words = set(words)

print(len(unique_words))
# Out:
# Enter a sentence: good morning
# 2

# %% [markdown]
# **Dictionary**

# %% [markdown]
# Student Performance Tracker using Dictionaries:
# Create a dictionary where:
# Keys are student names.
# Values are lists of their marks in 3 subjects.
# Write a code to:
# Add three new students with their marks.
# Calculate average marks for each student.
# Then add student(s) with the average marks into the dictionary.
# Convert the dictionary into a list of tuples and sort it by average marks.

# %%
students = {
    "Ali": [80, 75, 90],
    "Sara": [85, 88, 92]
}

students["Ahmed"] = [70, 65, 75]
students["Ayesha"] = [90, 95, 93]
students["Bilal"] = [60, 70, 65]

averages = {}

for name, marks in students.items():
    avg = sum(marks) / 3
    averages[name] = avg

for name, avg in averages.items():
    students[name] = students[name] + [avg]

student_list = list(averages.items())
student_list.sort(key=lambda x: x[1])

print(students)
print(student_list)
# Out:
# {'Ali': [80, 75, 90, 81.66666666666667], 'Sara': [85, 88, 92, 88.33333333333333], 'Ahmed': [70, 65, 75, 70.0], 'Ayesha': [90, 95, 93, 92.66666666666667], 'Bilal': [60, 70, 65, 65.0]}
# [('Bilal', 65.0), ('Ahmed', 70.0), ('Ali', 81.66666666666667), ('Sara', 88.33333333333333), ('Ayesha', 92.66666666666667)]

# %% [markdown]
# Shopping Cart Snapshot:
# Instructions:
# Create 3 products.
# Each product is a dictionary with:
# "info" → a tuple: (name, category)
# "price" → integer
# "ratings" → list of 3 numbers
# "tags" → set of 3 tags
# Store all products in a list called cart.
# Questions:
# 1.What is the category of the second product?
# 2.What is the total price of all products?
# 3.Find the average rating of the first product.
# 4.Combine all tags from the products (using |
# operator).
# 5.Add a new product product4 with your own
# data and update cart.

# %%
product1 = {
    "info": ("Notebook", "Stationery"),
    "price": 1200,
    "ratings": [4, 5, 4],
    "tags": {"school", "paper", "writing"}
}

product2 = {
    "info": ("Wireless Mouse", "Electronics"),
    "price": 2500,
    "ratings": [5, 4, 4],
    "tags": {"computer", "accessory", "wireless"}
}

product3 = {
    "info": ("Water Bottle", "Kitchen"),
    "price": 900,
    "ratings": [4, 4, 5],
    "tags": {"drink", "portable", "eco"}
}

cart = [product1, product2, product3]

second_product_category = cart[1]["info"][1]
print("1) Category of second product:", second_product_category)

total_price = sum(item["price"] for item in cart)
print("2) Total price of all products:", total_price)

first_product_ratings = cart[0]["ratings"]
average_rating_first = sum(first_product_ratings) / len(first_product_ratings)
print("3) Average rating of first product:", average_rating_first)

all_tags = set()
for item in cart:
    all_tags = all_tags | item["tags"]
print("4) Combined tags:", all_tags)

product4 = {
    "info": ("Desk Lamp", "Home"),
    "price": 1800,
    "ratings": [5, 5, 4],
    "tags": {"lighting", "decor", "LED"}
}

cart.append(product4)
print("5) Updated cart has", len(cart), "products.")
# Out:
# 1) Category of second product: Electronics
# 2) Total price of all products: 4600
# 3) Average rating of first product: 4.333333333333333
# 4) Combined tags: {'wireless', 'paper', 'writing', 'eco', 'computer', 'accessory', 'portable', 'drink', 'school'}
# 5) Updated cart has 4 products.
